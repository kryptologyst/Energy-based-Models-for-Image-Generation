# %% [markdown]
# # Energy-based Model Demo
#
# This notebook demonstrates how to use the Energy-based Model implementation for image generation.

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import sys

# Add src to path
sys.path.append('../src')

from models.ebm import EnergyBasedModel, EBMTrainer
from data.datasets import get_data_loaders
from utils.metrics import EBMMetrics
from configs.config import get_default_config, setup_reproducibility
